# %% [markdown]
# # Deliverable 1 - Retrieve Weather Data

# %%
# Imports
import pandas as pd
import numpy as np
import requests
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 785

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# Query URL
city_url = url + "&q=" + "Boston"
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d56deb95dd36c6bc49d09173fb8b7d18

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 55.67,
#   'feels_like': 55.17,
#   'temp_min': 51.76,
#   'temp_max': 57.99,
#   'pressure': 1008,
#   'humidity': 90},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 180},
#  'clouds': {'all': 100},
#  'dt': 1653010992,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1652951947,
#   'sunset': 1653004955},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kantang
# Processing Record 3 of Set 1 | chakwal
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bahia honda
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | soligalich
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | yar-sale
# Processing Record 13 of Set 1 | sirawai
# Processing Record 14 of Set 1 | balkhash
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | batemans bay
# Processing Record 17 of Set 1 | inhambane
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | kuytun
# Processing Record 21 of Set 1 | yulara
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | mineros
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | pacific grove
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | jevnaker
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | svetlyy
# Processing Record 31 of Set 1 | bhum
# Processing Record 32 of Set 1 | moose factory
# Processing Record 33 of Set 1 | vardo
# Processing Record 34 of Set 1 | sola
# Processing Record 35 of Set 1 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | miajadas
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | ondjiva
# Processing Record 42 of Set 1 | ust-kuyga
# Processing Record 43 of Set 1 | boralday
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | egvekinot
# Processing Record 46 of Set 1 | chara
# Processing Record 47 of Set 1 | frazao
# Processing Record 48 of Set 1 | havre-saint-pierre
# Processing Record 49 of Set 1 | bolonchen
# City not found. Skipping...
# Processing Record 50 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | stornoway
# Processing Record 5 of Set 2 | puerto escondido
# Processing Record 6 of Set 2 | borgosesia
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | sayyan
# Processing Record 9 of Set 2 | geraldton
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | upata
# Processing Record 15 of Set 2 | yerbogachen
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | kabinda
# Processing Record 18 of Set 2 | ahipara
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | cayenne
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | smithers
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | lorengau
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | shingu
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | lasa
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | morondava
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | abha
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | barranca
# Processing Record 44 of Set 2 | sokolo
# Processing Record 45 of Set 2 | cabedelo
# Processing Record 46 of Set 2 | carauari
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | saint-joseph
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | patan
# Processing Record 2 of Set 3 | amboasary
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | tiarei
# Processing Record 6 of Set 3 | gizo
# Processing Record 7 of Set 3 | muncar
# Processing Record 8 of Set 3 | katherine
# Processing Record 9 of Set 3 | te anau
# Processing Record 10 of Set 3 | rocha
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | opuwo
# Processing Record 13 of Set 3 | kavieng
# Processing Record 14 of Set 3 | aykhal
# Processing Record 15 of Set 3 | casino
# Processing Record 16 of Set 3 | fereydun kenar
# Processing Record 17 of Set 3 | fukue
# Processing Record 18 of Set 3 | lufilufi
# Processing Record 19 of Set 3 | gamba
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | sechura
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | at-bashi
# Processing Record 25 of Set 3 | neuquen
# Processing Record 26 of Set 3 | clifton
# Processing Record 27 of Set 3 | el cocuy
# Processing Record 28 of Set 3 | necochea
# Processing Record 29 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | alta floresta
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | paamiut
# Processing Record 35 of Set 3 | haines junction
# Processing Record 36 of Set 3 | denia
# Processing Record 37 of Set 3 | rosetown
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | moose jaw
# Processing Record 40 of Set 3 | nakhon phanom
# Processing Record 41 of Set 3 | sambava
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | codrington
# Processing Record 44 of Set 3 | ranot
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | noyabrsk
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | wejherowo
# Processing Record 50 of Set 3 | flin flon
# Processing Record 1 of Set 4 | pitimbu
# Processing Record 2 of Set 4 | esmeralda
# Processing Record 3 of Set 4 | matina
# Processing Record 4 of Set 4 | gao
# Processing Record 5 of Set 4 | hobyo
# Processing Record 6 of Set 4 | cassilandia
# Processing Record 7 of Set 4 | kingston
# Processing Record 8 of Set 4 | komsomolskiy
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | north bend
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | bosaso
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | tuktoyaktuk
# Processing Record 16 of Set 4 | gaspe
# Processing Record 17 of Set 4 | yantal
# Processing Record 18 of Set 4 | vila velha
# Processing Record 19 of Set 4 | khakhea
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | krasnyy chikoy
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | saravan
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | praia
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | sandovo
# Processing Record 30 of Set 4 | zemio
# Processing Record 31 of Set 4 | huntington
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | mugur-aksy
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | santa rosa
# Processing Record 36 of Set 4 | fuerte olimpo
# Processing Record 37 of Set 4 | charters towers
# Processing Record 38 of Set 4 | henties bay
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | ndele
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | lucapa
# Processing Record 43 of Set 4 | meghri
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | san quintin
# Processing Record 47 of Set 4 | cape town
# Processing Record 48 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | vaini
# Processing Record 1 of Set 5 | abong mbang
# Processing Record 2 of Set 5 | hervey bay
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | lamu
# Processing Record 5 of Set 5 | mikhaylovka
# Processing Record 6 of Set 5 | cabra
# Processing Record 7 of Set 5 | springdale
# Processing Record 8 of Set 5 | bima
# Processing Record 9 of Set 5 | puerto baquerizo moreno
# Processing Record 10 of Set 5 | liverpool
# Processing Record 11 of Set 5 | ketchikan
# Processing Record 12 of Set 5 | samarai
# Processing Record 13 of Set 5 | hermanus
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | kununurra
# Processing Record 16 of Set 5 | sinjah
# City not found. Skipping...
# Processing Record 17 of Set 5 | brownfield
# Processing Record 18 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | dicabisagan
# Processing Record 21 of Set 5 | lima
# Processing Record 22 of Set 5 | nioro
# Processing Record 23 of Set 5 | berezovka
# Processing Record 24 of Set 5 | kuli
# Processing Record 25 of Set 5 | mbandaka
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | seoul
# Processing Record 28 of Set 5 | copiapo
# Processing Record 29 of Set 5 | itaituba
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | chico
# Processing Record 32 of Set 5 | ban nahin
# Processing Record 33 of Set 5 | mao
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | khorramabad
# Processing Record 36 of Set 5 | matipo
# Processing Record 37 of Set 5 | salinopolis
# Processing Record 38 of Set 5 | galle
# Processing Record 39 of Set 5 | parrita
# Processing Record 40 of Set 5 | cairns
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | ossora
# Processing Record 43 of Set 5 | port-cartier
# Processing Record 44 of Set 5 | sawakin
# Processing Record 45 of Set 5 | jinotega
# Processing Record 46 of Set 5 | ugoofaaru
# Processing Record 47 of Set 5 | buchanan
# Processing Record 48 of Set 5 | gigmoto
# Processing Record 49 of Set 5 | westport
# Processing Record 50 of Set 5 | annau
# Processing Record 1 of Set 6 | khani
# Processing Record 2 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | itacare
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | baker city
# Processing Record 10 of Set 6 | isabela
# Processing Record 11 of Set 6 | prado
# Processing Record 12 of Set 6 | letlhakane
# Processing Record 13 of Set 6 | umm kaddadah
# Processing Record 14 of Set 6 | mogoytuy
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | sao jose da coroa grande
# Processing Record 17 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 6 | inta
# Processing Record 19 of Set 6 | santa maria da vitoria
# Processing Record 20 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 21 of Set 6 | qom
# Processing Record 22 of Set 6 | formosa do rio preto
# Processing Record 23 of Set 6 | mosquera
# Processing Record 24 of Set 6 | penzance
# Processing Record 25 of Set 6 | kulhudhuffushi
# Processing Record 26 of Set 6 | monrovia
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | marsh harbour
# Processing Record 29 of Set 6 | bambous virieux
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | kargasok
# Processing Record 32 of Set 6 | goderich
# Processing Record 33 of Set 6 | vila franca do campo
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | lovozero
# Processing Record 36 of Set 6 | mazamari
# Processing Record 37 of Set 6 | tasiilaq
# Processing Record 38 of Set 6 | londoko
# Processing Record 39 of Set 6 | lisakovsk
# Processing Record 40 of Set 6 | chifeng
# Processing Record 41 of Set 6 | nishihara
# Processing Record 42 of Set 6 | mandali
# Processing Record 43 of Set 6 | lakatoro
# Processing Record 44 of Set 6 | los llanos de aridane
# Processing Record 45 of Set 6 | provideniya
# Processing Record 46 of Set 6 | dalby
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | halifax
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | matay
# Processing Record 1 of Set 7 | katsuura
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | galich
# Processing Record 4 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 7 | kars
# Processing Record 7 of Set 7 | saint-paul-les-dax
# Processing Record 8 of Set 7 | pringsewu
# Processing Record 9 of Set 7 | meulaboh
# Processing Record 10 of Set 7 | gazanjyk
# Processing Record 11 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 12 of Set 7 | riohacha
# Processing Record 13 of Set 7 | fare
# Processing Record 14 of Set 7 | thompson
# Processing Record 15 of Set 7 | gagnoa
# Processing Record 16 of Set 7 | begowal
# Processing Record 17 of Set 7 | taltal
# Processing Record 18 of Set 7 | waipawa
# Processing Record 19 of Set 7 | port lincoln
# Processing Record 20 of Set 7 | san pedro
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | bonavista
# Processing Record 23 of Set 7 | bratsk
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | boende
# Processing Record 26 of Set 7 | coffs harbour
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | erenhot
# Processing Record 29 of Set 7 | hermosillo
# Processing Record 30 of Set 7 | humaita
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | masindi
# Processing Record 33 of Set 7 | namie
# Processing Record 34 of Set 7 | lockhart
# Processing Record 35 of Set 7 | mandalgovi
# Processing Record 36 of Set 7 | kingseat
# Processing Record 37 of Set 7 | boyolangu
# Processing Record 38 of Set 7 | aldan
# Processing Record 39 of Set 7 | bagan
# Processing Record 40 of Set 7 | ca mau
# Processing Record 41 of Set 7 | cuauhtemoc
# Processing Record 42 of Set 7 | lamar
# Processing Record 43 of Set 7 | coquimbo
# Processing Record 44 of Set 7 | praya
# Processing Record 45 of Set 7 | tiznit
# Processing Record 46 of Set 7 | byron bay
# Processing Record 47 of Set 7 | nizhneudinsk
# Processing Record 48 of Set 7 | tessalit
# Processing Record 49 of Set 7 | gaogou
# Processing Record 50 of Set 7 | teknaf
# Processing Record 1 of Set 8 | putina
# Processing Record 2 of Set 8 | uzumlu
# City not found. Skipping...
# Processing Record 3 of Set 8 | mago
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | prien
# Processing Record 6 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 8 | troitskoye
# Processing Record 8 of Set 8 | pitkyaranta
# Processing Record 9 of Set 8 | ughelli
# Processing Record 10 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 8 | evensk
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | hit
# Processing Record 14 of Set 8 | yautepec
# Processing Record 15 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 8 | sobolevo
# Processing Record 17 of Set 8 | gedo
# Processing Record 18 of Set 8 | yzeure
# Processing Record 19 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 8 | takoradi
# Processing Record 21 of Set 8 | touros
# Processing Record 22 of Set 8 | ambatondrazaka
# Processing Record 23 of Set 8 | zambrow
# Processing Record 24 of Set 8 | tenenkou
# Processing Record 25 of Set 8 | yokadouma
# Processing Record 26 of Set 8 | monsenhor gil
# Processing Record 27 of Set 8 | vostok
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | calvinia
# Processing Record 30 of Set 8 | gidam
# Processing Record 31 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 8 | manokwari
# Processing Record 33 of Set 8 | chalisgaon
# Processing Record 34 of Set 8 | hirara
# Processing Record 35 of Set 8 | kapoeta
# Processing Record 36 of Set 8 | bairiki
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | mercedes
# Processing Record 39 of Set 8 | namatanai
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | lalmohan
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | inongo
# Processing Record 44 of Set 8 | ridgecrest
# Processing Record 45 of Set 8 | belaya gora
# Processing Record 46 of Set 8 | mogadishu
# Processing Record 47 of Set 8 | surt
# Processing Record 48 of Set 8 | orlik
# Processing Record 49 of Set 8 | payson
# Processing Record 50 of Set 8 | les cayes
# Processing Record 1 of Set 9 | misratah
# Processing Record 2 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 3 of Set 9 | atambua
# Processing Record 4 of Set 9 | aguimes
# Processing Record 5 of Set 9 | nyurba
# Processing Record 6 of Set 9 | rawah
# Processing Record 7 of Set 9 | songea
# Processing Record 8 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 9 of Set 9 | alekseyevsk
# Processing Record 10 of Set 9 | vagur
# Processing Record 11 of Set 9 | gumdag
# Processing Record 12 of Set 9 | tecoanapa
# Processing Record 13 of Set 9 | tolaga bay
# Processing Record 14 of Set 9 | luena
# Processing Record 15 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 9 | labuhan
# Processing Record 17 of Set 9 | daru
# Processing Record 18 of Set 9 | kuopio
# Processing Record 19 of Set 9 | rawson
# Processing Record 20 of Set 9 | tomatlan
# Processing Record 21 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 22 of Set 9 | kitimat
# Processing Record 23 of Set 9 | xuddur
# Processing Record 24 of Set 9 | oshakati
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | patacamaya
# Processing Record 27 of Set 9 | severnyy
# Processing Record 28 of Set 9 | sehithwa
# Processing Record 29 of Set 9 | lompoc
# Processing Record 30 of Set 9 | michurinsk
# Processing Record 31 of Set 9 | kisangani
# Processing Record 32 of Set 9 | talnakh
# Processing Record 33 of Set 9 | langxiang
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | jawhar
# Processing Record 36 of Set 9 | cortland
# Processing Record 37 of Set 9 | dudinka
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 9 | uturoa
# Processing Record 41 of Set 9 | sitka
# Processing Record 42 of Set 9 | shieli
# Processing Record 43 of Set 9 | beringovskiy
# Processing Record 44 of Set 9 | dalvik
# Processing Record 45 of Set 9 | kamenka
# Processing Record 46 of Set 9 | kemijarvi
# Processing Record 47 of Set 9 | posadas
# Processing Record 48 of Set 9 | quelimane
# Processing Record 49 of Set 9 | kaspiysk
# Processing Record 50 of Set 9 | leningradskiy
# Processing Record 1 of Set 10 | port-gentil
# Processing Record 2 of Set 10 | teeli
# Processing Record 3 of Set 10 | cajamarca
# Processing Record 4 of Set 10 | puri
# Processing Record 5 of Set 10 | karratha
# Processing Record 6 of Set 10 | fairbanks
# Processing Record 7 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | aksu
# Processing Record 9 of Set 10 | doctor arroyo
# Processing Record 10 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 10 | greytown
# Processing Record 12 of Set 10 | chapais
# Processing Record 13 of Set 10 | paita
# Processing Record 14 of Set 10 | prince rupert
# Processing Record 15 of Set 10 | suining
# Processing Record 16 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 10 | irece
# Processing Record 18 of Set 10 | nikolayevsk-na-amure
# Processing Record 19 of Set 10 | ayan
# Processing Record 20 of Set 10 | slobozia
# Processing Record 21 of Set 10 | vestmanna
# Processing Record 22 of Set 10 | griffith
# Processing Record 23 of Set 10 | wainwright
# Processing Record 24 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 10 | duiwelskloof
# Processing Record 26 of Set 10 | khandyga
# Processing Record 27 of Set 10 | yinchuan
# Processing Record 28 of Set 10 | sabha
# Processing Record 29 of Set 10 | constitucion
# Processing Record 30 of Set 10 | pangai
# Processing Record 31 of Set 10 | leshukonskoye
# Processing Record 32 of Set 10 | san ramon de la nueva oran
# Processing Record 33 of Set 10 | eufaula
# Processing Record 34 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 35 of Set 10 | hinton
# Processing Record 36 of Set 10 | kanniyakumari
# Processing Record 37 of Set 10 | marfino
# Processing Record 38 of Set 10 | harrismith
# Processing Record 39 of Set 10 | kyshtovka
# Processing Record 40 of Set 10 | visnes
# Processing Record 41 of Set 10 | alamos
# Processing Record 42 of Set 10 | almaznyy
# Processing Record 43 of Set 10 | nelson bay
# Processing Record 44 of Set 10 | nenjiang
# Processing Record 45 of Set 10 | biloela
# Processing Record 46 of Set 10 | santa lucia
# Processing Record 47 of Set 10 | mount gambier
# Processing Record 48 of Set 10 | russell
# Processing Record 49 of Set 10 | acajutla
# Processing Record 50 of Set 10 | graaff-reinet
# Processing Record 1 of Set 11 | luderitz
# Processing Record 2 of Set 11 | sibu
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | mackenzie
# Processing Record 5 of Set 11 | yerofey pavlovich
# Processing Record 6 of Set 11 | codajas
# Processing Record 7 of Set 11 | sao joao da barra
# Processing Record 8 of Set 11 | mega
# Processing Record 9 of Set 11 | panlaitan
# Processing Record 10 of Set 11 | pisco
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | kokstad
# Processing Record 13 of Set 11 | loreto
# Processing Record 14 of Set 11 | salalah
# Processing Record 15 of Set 11 | barcelos
# Processing Record 16 of Set 11 | kokopo
# Processing Record 17 of Set 11 | naron
# Processing Record 18 of Set 11 | sangar
# Processing Record 19 of Set 11 | kiunga
# Processing Record 20 of Set 11 | havelock
# Processing Record 21 of Set 11 | chipinge
# Processing Record 22 of Set 11 | ponta delgada
# Processing Record 23 of Set 11 | villazon
# Processing Record 24 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 25 of Set 11 | safita
# Processing Record 26 of Set 11 | hammerfest
# Processing Record 27 of Set 11 | warmbad
# Processing Record 28 of Set 11 | valdosta
# Processing Record 29 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 11 | sioux lookout
# Processing Record 31 of Set 11 | sertanopolis
# Processing Record 32 of Set 11 | hannibal
# Processing Record 33 of Set 11 | pietarsaari
# Processing Record 34 of Set 11 | souillac
# Processing Record 35 of Set 11 | micheweni
# Processing Record 36 of Set 11 | ipixuna
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | verkhoyansk
# Processing Record 39 of Set 11 | washougal
# Processing Record 40 of Set 11 | pasinler
# Processing Record 41 of Set 11 | quirinopolis
# Processing Record 42 of Set 11 | matara
# Processing Record 43 of Set 11 | barauna
# Processing Record 44 of Set 11 | tashara
# Processing Record 45 of Set 11 | stephenville
# Processing Record 46 of Set 11 | dawlatabad
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | huilong
# Processing Record 49 of Set 11 | jardim
# Processing Record 50 of Set 11 | san vicente
# Processing Record 1 of Set 12 | concarneau
# Processing Record 2 of Set 12 | buala
# Processing Record 3 of Set 12 | zheleznodorozhnyy
# Processing Record 4 of Set 12 | nantucket
# Processing Record 5 of Set 12 | aswan
# Processing Record 6 of Set 12 | san andres
# Processing Record 7 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 12 | harper
# Processing Record 9 of Set 12 | bay roberts
# Processing Record 10 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 12 | ribeira brava
# Processing Record 13 of Set 12 | patea
# Processing Record 14 of Set 12 | eureka
# Processing Record 15 of Set 12 | syke
# Processing Record 16 of Set 12 | show low
# Processing Record 17 of Set 12 | makakilo city
# Processing Record 18 of Set 12 | banff
# Processing Record 19 of Set 12 | novyy urengoy
# Processing Record 20 of Set 12 | talcahuano
# Processing Record 21 of Set 12 | tabas
# Processing Record 22 of Set 12 | kota belud
# Processing Record 23 of Set 12 | brae
# Processing Record 24 of Set 12 | ponca city
# Processing Record 25 of Set 12 | huejuquilla el alto
# Processing Record 26 of Set 12 | praia da vitoria
# Processing Record 27 of Set 12 | oran
# Processing Record 28 of Set 12 | tevaitoa
# Processing Record 29 of Set 12 | bowen
# Processing Record 30 of Set 12 | saint-pierre
# Processing Record 31 of Set 12 | elat
# Processing Record 32 of Set 12 | padang
# Processing Record 33 of Set 12 | paramirim
# Processing Record 34 of Set 12 | veraval
# Processing Record 35 of Set 12 | shimoda
# Processing Record 36 of Set 12 | sokur
# Processing Record 37 of Set 12 | masvingo
# Processing Record 38 of Set 12 | nanjing
# Processing Record 39 of Set 12 | woodend
# Processing Record 40 of Set 12 | yanam
# Processing Record 41 of Set 12 | buraydah
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | korla
# Processing Record 44 of Set 12 | ocala
# Processing Record 45 of Set 12 | arman
# Processing Record 46 of Set 12 | fort nelson
# Processing Record 47 of Set 12 | tosya
# Processing Record 48 of Set 12 | nabire
# Processing Record 49 of Set 12 | almenara
# Processing Record 50 of Set 12 | kalyazin
# Processing Record 1 of Set 13 | faanui
# Processing Record 2 of Set 13 | turukhansk
# Processing Record 3 of Set 13 | ajdabiya
# Processing Record 4 of Set 13 | antofagasta
# Processing Record 5 of Set 13 | tahta
# Processing Record 6 of Set 13 | abu dhabi
# Processing Record 7 of Set 13 | aklavik
# Processing Record 8 of Set 13 | hede
# Processing Record 9 of Set 13 | kasane
# Processing Record 10 of Set 13 | green river
# Processing Record 11 of Set 13 | adrar
# Processing Record 12 of Set 13 | nome
# Processing Record 13 of Set 13 | lapeer
# Processing Record 14 of Set 13 | asosa
# Processing Record 15 of Set 13 | awbari
# Processing Record 16 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 13 | guanica
# Processing Record 18 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 13 | bintulu
# Processing Record 20 of Set 13 | piskivka
# Processing Record 21 of Set 13 | chicama
# Processing Record 22 of Set 13 | jalu
# Processing Record 23 of Set 13 | den helder
# Processing Record 24 of Set 13 | oranjestad
# Processing Record 25 of Set 13 | beloha
# Processing Record 26 of Set 13 | parainen
# Processing Record 27 of Set 13 | loiza
# Processing Record 28 of Set 13 | sergeyevka
# Processing Record 29 of Set 13 | mali idos
# City not found. Skipping...
# Processing Record 30 of Set 13 | itoman
# Processing Record 31 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 32 of Set 13 | chute-aux-outardes
# Processing Record 33 of Set 13 | bowmore
# Processing Record 34 of Set 13 | hongjiang
# Processing Record 35 of Set 13 | mohelnice
# Processing Record 36 of Set 13 | nuoro
# Processing Record 37 of Set 13 | muana
# Processing Record 38 of Set 13 | denpasar
# Processing Record 39 of Set 13 | kalmunai
# Processing Record 40 of Set 13 | san nicolas
# Processing Record 41 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 13 | santa ana
# Processing Record 43 of Set 13 | vachi
# Processing Record 44 of Set 13 | melfi
# Processing Record 45 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 13 | pentaplatanon
# Processing Record 47 of Set 13 | ust-ishim
# Processing Record 48 of Set 13 | bathsheba
# Processing Record 49 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 13 | eydhafushi
# Processing Record 1 of Set 14 | burica
# City not found. Skipping...
# Processing Record 2 of Set 14 | kendrapara
# Processing Record 3 of Set 14 | campina verde
# Processing Record 4 of Set 14 | mae sai
# Processing Record 5 of Set 14 | taldan
# Processing Record 6 of Set 14 | diamantino
# Processing Record 7 of Set 14 | biak
# Processing Record 8 of Set 14 | ixtapa
# Processing Record 9 of Set 14 | mpongwe
# Processing Record 10 of Set 14 | ukiah
# Processing Record 11 of Set 14 | ballina
# Processing Record 12 of Set 14 | sicuani
# Processing Record 13 of Set 14 | grindavik
# Processing Record 14 of Set 14 | simao
# Processing Record 15 of Set 14 | yate
# Processing Record 16 of Set 14 | ahuimanu
# Processing Record 17 of Set 14 | pemangkat
# Processing Record 18 of Set 14 | broken hill
# Processing Record 19 of Set 14 | hirekerur
# Processing Record 20 of Set 14 | pangnirtung
# Processing Record 21 of Set 14 | parksville
# Processing Record 22 of Set 14 | porbandar
# Processing Record 23 of Set 14 | vanimo
# Processing Record 24 of Set 14 | nalut
# Processing Record 25 of Set 14 | dzhebariki-khaya
# Processing Record 26 of Set 14 | riyadh
# Processing Record 27 of Set 14 | dhidhdhoo
# Processing Record 28 of Set 14 | tazovskiy
# Processing Record 29 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 14 | menongue
# Processing Record 31 of Set 14 | waingapu
# Processing Record 32 of Set 14 | barcelona
# Processing Record 33 of Set 14 | cochrane
# Processing Record 34 of Set 14 | anchorage
# Processing Record 35 of Set 14 | jacmel
# Processing Record 36 of Set 14 | sorong
# Processing Record 37 of Set 14 | saint-denis
# Processing Record 38 of Set 14 | dindori
# Processing Record 39 of Set 14 | kudat
# Processing Record 40 of Set 14 | isla mujeres
# Processing Record 41 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 42 of Set 14 | springbok
# Processing Record 43 of Set 14 | kjollefjord
# Processing Record 44 of Set 14 | valdivia
# Processing Record 45 of Set 14 | tateyama
# Processing Record 46 of Set 14 | joshimath
# Processing Record 47 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 14 | dzialdowo
# Processing Record 49 of Set 14 | siirt
# Processing Record 50 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 1 of Set 15 | airai
# Processing Record 2 of Set 15 | sakti
# Processing Record 3 of Set 15 | castelnaudary
# Processing Record 4 of Set 15 | bharatpur
# Processing Record 5 of Set 15 | akyab
# Processing Record 6 of Set 15 | lumberton
# Processing Record 7 of Set 15 | podosinovets
# Processing Record 8 of Set 15 | nurota
# Processing Record 9 of Set 15 | half moon bay
# Processing Record 10 of Set 15 | alice springs
# Processing Record 11 of Set 15 | port blair
# Processing Record 12 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 15 | san francisco
# Processing Record 14 of Set 15 | elizabeth city
# Processing Record 15 of Set 15 | pumiao
# Processing Record 16 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 17 of Set 15 | whitianga
# Processing Record 18 of Set 15 | iisalmi
# Processing Record 19 of Set 15 | esna
# Processing Record 20 of Set 15 | ganzhou
# Processing Record 21 of Set 15 | blagoyevo
# Processing Record 22 of Set 15 | ambilobe
# Processing Record 23 of Set 15 | muros
# Processing Record 24 of Set 15 | suyan
# Processing Record 25 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 26 of Set 15 | sao filipe
# Processing Record 27 of Set 15 | kutum
# Processing Record 28 of Set 15 | presidencia roque saenz pena
# Processing Record 29 of Set 15 | omutinskoye
# City not found. Skipping...
# Processing Record 30 of Set 15 | robertson
# Processing Record 31 of Set 15 | solok
# Processing Record 32 of Set 15 | lodwar
# Processing Record 33 of Set 15 | pryazha
# Processing Record 34 of Set 15 | port macquarie
# Processing Record 35 of Set 15 | zabolotovka
# Processing Record 36 of Set 15 | tocopilla
# Processing Record 37 of Set 15 | krasnaya gora
# Processing Record 38 of Set 15 | havoysund
# Processing Record 39 of Set 15 | huanren
# Processing Record 40 of Set 15 | christchurch
# Processing Record 41 of Set 15 | hami
# Processing Record 42 of Set 15 | mamakan
# Processing Record 43 of Set 15 | shaunavon
# Processing Record 44 of Set 15 | lumphat
# Processing Record 45 of Set 15 | port hardy
# Processing Record 46 of Set 15 | sorland
# Processing Record 47 of Set 15 | acapulco
# Processing Record 48 of Set 15 | yuxia
# Processing Record 49 of Set 15 | beachwood
# Processing Record 50 of Set 15 | davila
# Processing Record 1 of Set 16 | jati
# Processing Record 2 of Set 16 | lososina
# Processing Record 3 of Set 16 | methoni
# Processing Record 4 of Set 16 | mehamn
# Processing Record 5 of Set 16 | riachao
# Processing Record 6 of Set 16 | arrifes
# Processing Record 7 of Set 16 | puerto princesa
# Processing Record 8 of Set 16 | am timan
# Processing Record 9 of Set 16 | olafsvik
# Processing Record 10 of Set 16 | berlevag
# Processing Record 11 of Set 16 | alpena
# Processing Record 12 of Set 16 | solotcha
# Processing Record 13 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 16 | lazaro cardenas
# Processing Record 15 of Set 16 | lalomanu
# City not found. Skipping...
# Processing Record 16 of Set 16 | curup
# Processing Record 17 of Set 16 | launceston
# Processing Record 18 of Set 16 | shymkent
# Processing Record 19 of Set 16 | yining
# Processing Record 20 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 16 | san cristobal
# Processing Record 22 of Set 16 | goundam
# Processing Record 23 of Set 16 | belmonte
# Processing Record 24 of Set 16 | betioky
# Processing Record 25 of Set 16 | manzhouli
# Processing Record 26 of Set 16 | muzquiz
# City not found. Skipping...
# Processing Record 27 of Set 16 | nizhnyaya omka
# Processing Record 28 of Set 16 | keetmanshoop
# Processing Record 29 of Set 16 | birnin kebbi
# Processing Record 30 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 16 | santa cruz
# Processing Record 32 of Set 16 | vestmannaeyjar
# Processing Record 33 of Set 16 | san carlos de bariloche
# Processing Record 34 of Set 16 | maniitsoq
# Processing Record 35 of Set 16 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 707                  Betioky      MG -23.7167   44.3833     64.08        76
# 708                Manzhouli      CN  49.6000  117.4333     73.54        24
# 709           Nizhnyaya Omka      RU  55.4338   74.9426     55.72        59
# 710             Keetmanshoop      NA -26.5833   18.1333     47.55        68
# 711             Birnin Kebbi      NG  12.4539    4.1975     88.34        43
# 712               Santa Cruz      BO -17.8000  -63.1667     51.26        76
# 713           Vestmannaeyjar      IS  63.4427  -20.2734     49.01        87
# 714  San Carlos De Bariloche      AR -41.1456  -71.3082     44.24        70
# 715                Maniitsoq      GL  65.4167  -52.9000     36.79        68
# 716                     Poum      NC -20.2333  164.0167     78.08        78
#
#      Cloudiness  Wind Speed Current Description
# 707           0        4.16           clear sky
# 708          52       17.63       broken clouds
# 709          59       17.85       broken clouds
# 710          87       17.34     overcast clouds
# 711           1       10.18           clear sky
# 712          13        5.75          few clouds
# 713          98       16.26     overcast clouds
# 714         100        4.79          light rain
# 715          83        4.97       broken clouds
# 716           0       11.74           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# END OF DELIVERABLE 1

# %%
# FLORENCIO RUSTRIAN MONROY
